# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
Graphtype=nx.DiGraph()
G = nx.read_edgelist("web-Google.txt", create_using=Graphtype, nodetype=int, data=(('weight', float),))
nx.info
# Out:
# <function networkx.classes.function.info(G, n=None)>

# %%
nx.number_of_nodes(G)
# Out:
# 875713

# %%
nx.number_of_edges(G)
# Out:
# 5105039

# %%
nx.shortest_path_length(G, source=None, target=None, weight=None)
# Out:
# <generator object all_pairs_shortest_path_length at 0x000002B736955B48>

# %%
p=nx.shortest_path_length(G,source=0)

# %%
p
# Out:
# {0: 0,
#  11342: 1,
#  824020: 1,
#  867923: 1,
#  891835: 1,
#  27469: 2,
#  38716: 2,
#  309564: 2,
#  322178: 2,
#  387543: 2,
#  427436: 2,
#  538214: 2,
#  638706: 2,
#  645018: 2,
#  835220: 2,
#  856657: 2,
#  91807: 2,
#  417728: 2,
#  438493: 2,
#  500627: 2,
#  535748: 2,
#  695578: 2,
#  136593: 2,
#  414038: 2,
#  523684: 2,
#  760842: 2,
#  815602: 2,
#  846213: 2,
#  857527: 2,
#  112028: 2,
#  235849: 2,
#  302284: 2,
#  451592: 2,
#  693969: 2,
#  227142: 3,
#  316308: 3,
#  316420: 3,
#  435804: 3,
#  588022: 3,
#  659942: 3,
#  720341: 3,
#  828241: 3,
#  3501: 3,
#  416555: 3,
#  428822: 3,
#  684417: 3,
#  765654: 3,
#  789355: 3,
#  795148: 3,
#  12303: 3,
#  115472: 3,
#  118398: 3,
#  169762: 3,
#  294155: 3,
#  332399: 3,
#  367595: 3,
#  483838: 3,
#  499324: 3,
#  556570: 3,
#  571331: 3,
#  701087: 3,
#  740065: 3,
#  784413: 3,
#  798461: 3,
#  858643: 3,
#  914941: 3,
#  39711: 3,
#  240416: 3,
#  754862: 3,
#  205034: 3,
#  477647: 3,
#  558815: 3,
# ...

# %%
N = G.order()
K= G.size()
avg_deg = K/N

# %%
N
# Out:
# 875713

# %%
K
# Out:
# 5105039

# %%
avg_deg
# Out:
# 5.829580010802626

# %%
nx.number_strongly_connected_components(G)
# Out:
# 371764

# %%
nx.number_weakly_connected_components(G)
# Out:
# 2746

# %%
nx.draw_networkx(G)

# %% [markdown]
# #shortest path length distance reference
# https://networkx.github.io/documentation/networkx-1.9/reference/generated/networkx.algorithms.shortest_paths.generic.shortest_path_length.html

# %%
nx.center(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-16-e37b5f8ae210> in <module>
# ----> 1 nx.center(G)
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\algorithms\distance_measures.py in center(G, e, usebounds)
#     351         return extrema_bounding(G, compute="center")
#     352     if e is None:
# --> 353         e = eccentricity(G)
#     354     radius = min(e.values())
#     355     p = [v for v in e if e[v] == radius]
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\algorithms\distance_measures.py in eccentricity(G, v, sp)
#     239                 msg = ('Found infinite path length because the graph is not'
#     240                        ' connected')
# --> 241             raise networkx.NetworkXError(msg)
#     242
#     243         e[n] = max(length.values())
#
# ...

# %%
nx.diameter(G, e=None, usebounds=False)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-17-ec931c41fd7f> in <module>
# ----> 1 nx.diameter(G, e=None, usebounds=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\algorithms\distance_measures.py in diameter(G, e, usebounds)
#     274         return extrema_bounding(G, compute="diameter")
#     275     if e is None:
# --> 276         e = eccentricity(G)
#     277     return max(e.values())
#     278
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\algorithms\distance_measures.py in eccentricity(G, v, sp)
#     239                 msg = ('Found infinite path length because the graph is not'
#     240                        ' connected')
# --> 241             raise networkx.NetworkXError(msg)
#     242
#     243         e[n] = max(length.values())
#
# NetworkXError: Found infinite path length because the digraph is not strongly connected
